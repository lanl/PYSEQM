# %% [markdown]
# # Example of geometry optimization
# ## Batch of two molecules

# %%
import torch
from seqm.seqm_functions.constants import Constants
from seqm.Molecule import Molecule
from seqm.MolecularDynamics import Geometry_Optimization_SD
from seqm.seqm_functions.read_xyz import read_xyz

torch.set_default_dtype(torch.float64)
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
# %%time

species = torch.as_tensor([[8,6,1,1],
                           [8,6,1,1],
                           [8,1,1,0]], # zero-padding for batching
                          dtype=torch.int64, device=device)

coordinates = torch.tensor([
                              [
                               [0.00,    0.00,    0.00],
                               [1.22,    0.00,    0.00],
                               [1.82,    0.94,    0.00],
                               [1.82,   -0.94,    0.00]
                              ],
                              [
                               [0.00,    0.00,    0.00],
                               [1.22,    0.00,    0.00],
                               [1.82,    0.94,    0.00],
                               [1.82,   -0.94,    0.00]
                              ],
                              [
                               [ 0.00,    0.00,    0.00],
                               [ 0.96,    0.00,    0.00],
                               [-0.45,   -0.57,    0.67],
                               [0.0,0.0,0.0]            # zero-padding for batching
                              ]
                            ], device=device)

const = Constants().to(device)
#may need to add scaling factor for length and energy on const, check constants.py

elements = [0]+sorted(set(species.reshape(-1).tolist()))
seqm_parameters = {
                   'method' : 'AM1',  # AM1, MNDO, PM#
                   'scf_eps' : 1.0e-6,  # unit eV, change of electric energy, as nuclear energy doesnt' change during SCF
                   'scf_converger' : [2,0.0], # converger used for scf loop
                                         # [0, 0.1], [0, alpha] constant mixing, P = alpha*P + (1.0-alpha)*Pnew
                                         # [1], adaptive mixing
                                         # [2], adaptive mixing, then pulay
                   'sp2' : [False, 1.0e-5],  # whether to use sp2 algorithm in scf loop,
                                            #[True, eps] or [False], eps for SP2 conve criteria
                   'elements' : elements, #[0,1,6,8],
                   'learned' : [], # learned parameters name list, e.g ['U_ss']
                   #'parameter_file_dir' : '../seqm/params/', # file directory for other required parameters
                   'pair_outer_cutoff' : 1.0e10, # consistent with the unit on coordinates
                   'eig' : True
                   }

molecule = Molecule(const, seqm_parameters, coordinates, species).to(device)

opt =  Geometry_Optimization_SD(seqm_parameters, alpha=0.008, force_tol=1.0e-2, max_evl=400).to(device)
max_force, dE =  opt.run(molecule)
# Out:
# Step,  Max_Force,      Etot(eV),     dE(eV)
# 1      1.796659e+00 ||-1.362050e+00 -1.362050e+00 ||-1.362050e+00 -1.362050e+00 ||-2.392370e+00 -2.392370e+00
# 2      1.400939e+00 ||-1.363489e+00 -1.439058e-03 ||-1.363489e+00 -1.439058e-03 ||-2.449955e+00 -5.758453e-02
# 3      1.153429e+00 ||-1.364422e+00 -9.335565e-04 ||-1.364422e+00 -9.335565e-04 ||-2.485697e+00 -3.574174e-02
# 4      9.636769e-01 ||-1.364870e+00 -4.476099e-04 ||-1.364870e+00 -4.476099e-04 ||-2.510563e+00 -2.486624e-02
# 5      8.074885e-01 ||-1.365146e+00 -2.757984e-04 ||-1.365146e+00 -2.757984e-04 ||-2.528016e+00 -1.745273e-02
# 6      6.766222e-01 ||-1.365288e+00 -1.425080e-04 ||-1.365288e+00 -1.425080e-04 ||-2.540260e+00 -1.224393e-02
# 29      1.136570e-02 ||-1.365485e+00 -6.329731e-08 ||-1.365485e+00 -6.329731e-08 ||-2.568865e+00 -3.594638e-06
# 30      9.966700e-03 ||-1.365485e+00 -6.566938e-08 ||-1.365485e+00 -6.566938e-08 ||-2.568867e+00 -2.558574e-06
# converged with 30 step, Max Force = 9.966700e-03 (eV/Ang), dE = -8.966376e-07 (eV)
# CPU times: user 5.58 s, sys: 168 ms, total: 5.75 s
# Wall time: 5.73 s

# %%
def save_xyz(molecules, name, Forces = False):
    for i in range(0,len(molecules)):
        fn = name + "." + i + ".xyz"
        f = open(fn,'a+')
        f.write("{}\Etot = {:12.6f} \n".format(
                                torch.sum(molecules.species[i]>0),  molecules.Etot[i]))

        for atom in range(molecules.coordinates.shape[1]):
            if molecules.species[i,atom]>0:
                if Forces:
                    f.write("{} {:15.5f} {:15.5f} {:15.5f} {:15.5f} {:15.5f} {:15.5f} \n".format(
                                                molecules.const.label[molecules.species[i,atom].item()],
                                                molecules.coordinates[i,atom,0],
                                                molecules.coordinates[i,atom,1],
                                                molecules.coordinates[i,atom,2], 
                                                molecules.forces[i,atom,0],
                                                molecules.forces[i,atom,1],
                                                molecules.forces[i,atom,2],
                                                )
                else:
                     f.write("{} {:15.5f} {:15.5f} {:15.5f}\n".format(
                                                molecules.const.label[molecules.species[i,atom].item()],
                                                molecules.coordinates[i,atom,0],
                                                molecules.coordinates[i,atom,1],
                                                molecules.coordinates[i,atom,2], 
                                                )
        f.close()

# %% [markdown]
# ### Final forces and optimized geometry

# %%
molecule.force
# Out:
# tensor([[[ 9.9667e-03, -2.8699e-14, -4.3301e-15],
#          [-9.4592e-03,  1.8697e-13,  2.6211e-15],
#          [-2.5373e-04,  1.3308e-03,  4.2835e-15],
#          [-2.5373e-04, -1.3308e-03, -2.5745e-15]],
#
#         [[ 9.9667e-03, -2.8699e-14, -4.3301e-15],
#          [-9.4592e-03,  1.8697e-13,  2.6211e-15],
#          [-2.5373e-04,  1.3308e-03,  4.2835e-15],
#          [-2.5373e-04, -1.3308e-03, -2.5745e-15]],
#
#         [[-3.3919e-03,  3.5531e-03, -4.1765e-03],
#          [-6.1924e-03, -4.9384e-03,  5.8048e-03],
#          [ 9.5843e-03,  1.3853e-03, -1.6283e-03],
#          [-0.0000e+00, -0.0000e+00, -0.0000e+00]]], device='cuda:0')

# %%
molecule.coordinates
# Out:
# tensor([[[-1.5705e-03, -4.3565e-16,  4.1913e-16],
#          [ 1.2257e+00,  1.4420e-15, -1.5915e-16],
#          [ 1.8180e+00,  9.3933e-01, -1.7557e-16],
#          [ 1.8180e+00, -9.3933e-01, -8.4408e-17]],
#
#         [[-1.5705e-03, -4.3565e-16,  4.1913e-16],
#          [ 1.2257e+00,  1.4420e-15, -1.5915e-16],
#          [ 1.8180e+00,  9.3933e-01, -1.7557e-16],
#          [ 1.8180e+00, -9.3933e-01, -8.4408e-17]],
#
#         [[-3.8492e-02,  2.8403e-02, -3.3386e-02],
#          [ 9.1673e-01, -4.1681e-02,  4.8993e-02],
#          [-3.6823e-01, -5.5672e-01,  6.5439e-01],
#          [ 0.0000e+00,  0.0000e+00,  0.0000e+00]]], device='cuda:0',
#        requires_grad=True)

# %% [markdown]
# ## Reading starting geometries from .xyz
# ### Only molecules of the same length are currently supported for batched xyz_reader.

# %%
# %%time
torch.manual_seed(0)
files = ['coronene.xyz', 'coronene.xyz']

species, coordinates = read_xyz(files)
species = torch.as_tensor(species,dtype=torch.int64, device=device)[:]
coordinates = torch.tensor(coordinates, device=device)[:]
const = Constants().to(device)
#may need to add scaling factor for length and energy on const, check constants.py

elements = [0]+sorted(set(species.reshape(-1).tolist()))
seqm_parameters = {
                   'method' : 'AM1',  # AM1, MNDO, PM#
                   'scf_eps' : 1.0e-6,  # unit eV, change of electric energy, as nuclear energy doesnt' change during SCF
                   'scf_converger' : [2,0.0], # converger used for scf loop
                                         # [0, 0.1], [0, alpha] constant mixing, P = alpha*P + (1.0-alpha)*Pnew
                                         # [1], adaptive mixing
                                         # [2], adaptive mixing, then pulay
                   'sp2' : [False, 1.0e-5],  # whether to use sp2 algorithm in scf loop,
                                            #[True, eps] or [False], eps for SP2 conve criteria
                   'elements' : elements, #[0,1,6,8],
                   'learned' : [], # learned parameters name list, e.g ['U_ss']
                   #'parameter_file_dir' : '../seqm/params/', # file directory for other required parameters
                   'pair_outer_cutoff' : 1.0e10, # consistent with the unit on coordinates
                   'eig' : True
                   }

molecule = Molecule(const, seqm_parameters, coordinates, species).to(device)

opt =  Geometry_Optimization_SD(seqm_parameters, alpha=0.012, force_tol=1.0e-2, max_evl=400).to(device)
max_force, dE =  opt.run(molecule)
# Out:
# Step,  Max_Force,      Etot(eV),     dE(eV)
# 1      6.239775e-01 ||4.242794e+00 4.242794e+00 ||4.242794e+00 4.242794e+00
# 2      3.792450e-01 ||4.186331e+00 -5.646306e-02 ||4.186331e+00 -5.646306e-02
# 3      1.358503e-01 ||4.178391e+00 -7.939461e-03 ||4.178391e+00 -7.939343e-03
# 4      1.010208e-01 ||4.176503e+00 -1.888181e-03 ||4.176501e+00 -1.890548e-03
# 5      6.808064e-02 ||4.175763e+00 -7.401234e-04 ||4.175762e+00 -7.387120e-04
# 6      5.526943e-02 ||4.175299e+00 -4.644478e-04 ||4.175301e+00 -4.614277e-04
# 7      4.481349e-02 ||4.174941e+00 -3.578210e-04 ||4.174942e+00 -3.588038e-04
# 8      3.944494e-02 ||4.174646e+00 -2.943534e-04 ||4.174647e+00 -2.951812e-04
# 9      3.848409e-02 ||4.174399e+00 -2.478334e-04 ||4.174399e+00 -2.478954e-04
# 10      3.466781e-02 ||4.174187e+00 -2.115148e-04 ||4.174187e+00 -2.119733e-04
# 11      3.324669e-02 ||4.174005e+00 -1.820248e-04 ||4.174005e+00 -1.818222e-04
# 12      3.045443e-02 ||4.173848e+00 -1.573619e-04 ||4.173848e+00 -1.574043e-04
# 13      2.875211e-02 ||4.173711e+00 -1.365529e-04 ||4.173711e+00 -1.365416e-04
# 14      2.656944e-02 ||4.173593e+00 -1.180427e-04 ||4.173593e+00 -1.180433e-04
# 15      2.504082e-02 ||4.173490e+00 -1.031962e-04 ||4.173490e+00 -1.032110e-04
# 16      2.338272e-02 ||4.173399e+00 -9.094008e-05 ||4.173399e+00 -9.092771e-05
# 17      2.188853e-02 ||4.173319e+00 -7.951168e-05 ||4.173319e+00 -7.954338e-05
# 18      2.059380e-02 ||4.173249e+00 -7.022381e-05 ||4.173249e+00 -7.021448e-05
# 19      1.926854e-02 ||4.173188e+00 -6.148035e-05 ||4.173188e+00 -6.148119e-05
# 20      1.814040e-02 ||4.173133e+00 -5.434135e-05 ||4.173133e+00 -5.432938e-05
# 21      1.697619e-02 ||4.173086e+00 -4.759789e-05 ||4.173086e+00 -4.760760e-05
# 22      1.598093e-02 ||4.173044e+00 -4.209325e-05 ||4.173044e+00 -4.208675e-05
# 23      1.483665e-02 ||4.173007e+00 -3.674563e-05 ||4.173007e+00 -3.675348e-05
# 24      1.407185e-02 ||4.172975e+00 -3.239474e-05 ||4.172975e+00 -3.238902e-05
# 25      1.306747e-02 ||4.172946e+00 -2.857217e-05 ||4.172946e+00 -2.855755e-05
# 26      1.240134e-02 ||4.172921e+00 -2.515300e-05 ||4.172921e+00 -2.518284e-05
# 27      1.152354e-02 ||4.172899e+00 -2.219006e-05 ||4.172899e+00 -2.221673e-05
# 28      1.079312e-02 ||4.172879e+00 -1.943875e-05 ||4.172879e+00 -1.941148e-05
# 29      1.012170e-02 ||4.172862e+00 -1.702622e-05 ||4.172862e+00 -1.700965e-05
# 30      9.505021e-03 ||4.172847e+00 -1.512660e-05 ||4.172847e+00 -1.511995e-05
# converged with 30 step, Max Force = 9.505021e-03 (eV/Ang), dE = -1.512327e-05 (eV)
# CPU times: user 2min 22s, sys: 2.9 s, total: 2min 24s
# Wall time: 8.76 s

# %% [markdown]
# ### Alternatively, use zero-padding in .xyz files for molecules of different lengths.

# %%
# %%time
torch.manual_seed(0)
files = ['coronene.xyz', 'benzene_zero_pad.xyz']

species, coordinates = read_xyz(files)
species = torch.as_tensor(species,dtype=torch.int64, device=device)[:]
coordinates = torch.tensor(coordinates, device=device)[:]
const = Constants().to(device)
#may need to add scaling factor for length and energy on const, check constants.py

elements = [0]+sorted(set(species.reshape(-1).tolist()))
seqm_parameters = {
                   'method' : 'AM1',  # AM1, MNDO, PM#
                   'scf_eps' : 1.0e-6,  # unit eV, change of electric energy, as nuclear energy doesnt' change during SCF
                   'scf_converger' : [2,0.0], # converger used for scf loop
                                         # [0, 0.1], [0, alpha] constant mixing, P = alpha*P + (1.0-alpha)*Pnew
                                         # [1], adaptive mixing
                                         # [2], adaptive mixing, then pulay
                   'sp2' : [False, 1.0e-5],  # whether to use sp2 algorithm in scf loop,
                                            #[True, eps] or [False], eps for SP2 conve criteria
                   'elements' : elements, #[0,1,6,8],
                   'learned' : [], # learned parameters name list, e.g ['U_ss']
                   #'parameter_file_dir' : '../seqm/params/', # file directory for other required parameters
                   'pair_outer_cutoff' : 1.0e10, # consistent with the unit on coordinates
                   'eig' : True
                   }

molecule = Molecule(const, seqm_parameters, coordinates, species).to(device)

opt =  Geometry_Optimization_SD(seqm_parameters, alpha=0.012, force_tol=1.0e-2, max_evl=1000).to(device)
max_force, dE =  opt.run(molecule)
# Out:
# Step,  Max_Force,      Etot(eV),     dE(eV)
